# %% [markdown]
# <a href="https://colab.research.google.com/github/yashguptaab99/Credit-Card-Fraud-Detection/blob/master/Credit_Card_Fraud_detection_Deep_Learning_with_Sampling_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import seaborn as sns
import tensorflow
import keras
np.random.seed(2)

# %% [markdown]
# # Importing Data

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/creditcard.csv')

# %%
data
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# Checking missing values

# %%
data.isna().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %% [markdown]
# # Preprocessing Data

# %%
data = data.drop(columns = 'Time')
data
# Out:
#                V1         V2        V3  ...       V28  Amount  Class
# 0       -1.359807  -0.072781  2.536347  ... -0.021053  149.62      0
# 1        1.191857   0.266151  0.166480  ...  0.014724    2.69      0
# 2       -1.358354  -1.340163  1.773209  ... -0.059752  378.66      0
# 3       -0.966272  -0.185226  1.792993  ...  0.061458  123.50      0
# 4       -1.158233   0.877737  1.548718  ...  0.215153   69.99      0
# ...           ...        ...       ...  ...       ...     ...    ...
# 284802 -11.881118  10.071785 -9.834783  ...  0.823731    0.77      0
# 284803  -0.732789  -0.055080  2.035030  ... -0.053527   24.79      0
# 284804   1.919565  -0.301254 -3.249640  ... -0.026561   67.88      0
# 284805  -0.240440   0.530483  0.702510  ...  0.104533   10.00      0
# 284806  -0.533413  -0.189733  0.703337  ...  0.013649  217.00      0
#
# [284807 rows x 30 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data['Amount'] = sc.fit_transform(data['Amount'].values.reshape(-1,1))
data
# Out:
#                V1         V2        V3  ...       V28    Amount  Class
# 0       -1.359807  -0.072781  2.536347  ... -0.021053  0.244964      0
# 1        1.191857   0.266151  0.166480  ...  0.014724 -0.342475      0
# 2       -1.358354  -1.340163  1.773209  ... -0.059752  1.160686      0
# 3       -0.966272  -0.185226  1.792993  ...  0.061458  0.140534      0
# 4       -1.158233   0.877737  1.548718  ...  0.215153 -0.073403      0
# ...           ...        ...       ...  ...       ...       ...    ...
# 284802 -11.881118  10.071785 -9.834783  ...  0.823731 -0.350151      0
# 284803  -0.732789  -0.055080  2.035030  ... -0.053527 -0.254117      0
# 284804   1.919565  -0.301254 -3.249640  ... -0.026561 -0.081839      0
# 284805  -0.240440   0.530483  0.702510  ...  0.104533 -0.313249      0
# 284806  -0.533413  -0.189733  0.703337  ...  0.013649  0.514355      0
#
# [284807 rows x 30 columns]

# %%
X = data.iloc[:, data.columns != 'Class']
y = data.iloc[:, data.columns == 'Class']

# %%
X
# Out:
#                V1         V2        V3  ...       V27       V28    Amount
# 0       -1.359807  -0.072781  2.536347  ...  0.133558 -0.021053  0.244964
# 1        1.191857   0.266151  0.166480  ... -0.008983  0.014724 -0.342475
# 2       -1.358354  -1.340163  1.773209  ... -0.055353 -0.059752  1.160686
# 3       -0.966272  -0.185226  1.792993  ...  0.062723  0.061458  0.140534
# 4       -1.158233   0.877737  1.548718  ...  0.219422  0.215153 -0.073403
# ...           ...        ...       ...  ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783  ...  0.943651  0.823731 -0.350151
# 284803  -0.732789  -0.055080  2.035030  ...  0.068472 -0.053527 -0.254117
# 284804   1.919565  -0.301254 -3.249640  ...  0.004455 -0.026561 -0.081839
# 284805  -0.240440   0.530483  0.702510  ...  0.108821  0.104533 -0.313249
# 284806  -0.533413  -0.189733  0.703337  ... -0.002415  0.013649  0.514355
#
# [284807 rows x 29 columns]

# %%
y
# Out:
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 1 columns]

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=0)

# %%
X_train.shape
# Out:
# (199364, 29)

# %%
X_train.shape
# Out:
# (199364, 29)

# %%
X_train
# Out:
#               V1        V2        V3  ...       V27       V28    Amount
# 161145 -0.132066  0.107044 -0.650588  ...  0.306395  0.074817 -0.161761
# 204520  2.125994  0.014207 -1.514760  ... -0.068267 -0.057678 -0.345313
# 182659 -0.086694  0.166240  1.573127  ... -1.201571 -1.139931  0.326845
# 25117   1.352339 -0.534984  0.555143  ...  0.013746  0.016152 -0.329401
# 227642 -1.526760  0.647782  0.615391  ...  0.065022  0.147294  0.006398
# ...          ...       ...       ...  ...       ...       ...       ...
# 211543 -1.321976  1.138686 -0.940861  ... -0.463125 -0.010589 -0.153765
# 86293  -0.627810  0.918729  1.478453  ...  0.145939  0.110400 -0.253317
# 122579  1.512602 -0.949435 -0.219062  ... -0.001415  0.003665 -0.213696
# 152315  1.798863 -1.699791 -0.142182  ... -0.033616 -0.032471  0.331683
# 117952 -0.589400  0.747828  1.784781  ...  0.086592  0.118084 -0.289300
#
# [199364 rows x 29 columns]

# %%
X_test
# Out:
#               V1        V2        V3  ...       V27       V28    Amount
# 183484 -0.323334  1.057455 -0.048341  ...  0.108494  0.161139 -0.193306
# 255448 -0.349718  0.932619  0.142992  ...  0.076830  0.175562 -0.345313
# 244749 -1.614711 -2.406570  0.326194  ...  0.286285  0.437322  0.030587
# 63919  -2.477184  0.860613  1.441850  ... -0.510060 -0.660533  0.878181
# 11475   1.338831 -0.547264  0.737389  ... -0.002769  0.003272 -0.333239
# ...          ...       ...       ...  ...       ...       ...       ...
# 208059 -0.429070  0.712074  0.675855  ... -0.150931 -0.111220 -0.233487
# 260930 -4.673996 -3.716208 -1.486611  ...  0.973848 -1.566714  1.777950
# 75125  -1.215390  1.379556  0.438732  ...  0.234356 -0.035339 -0.125338
# 37292  -0.632439  1.212284  1.388188  ...  0.345269  0.168419 -0.324643
# 240913 -0.252855  1.854028  0.149808  ...  0.360196  0.206837 -0.310890
#
# [85443 rows x 29 columns]

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
print(X_train)
# Out:
# [[-1.32066260e-01  1.07043551e-01 -6.50588173e-01 ...  3.06394657e-01
#    7.48169663e-02 -1.61761045e-01]
#  [ 2.12599441e+00  1.42074055e-02 -1.51476031e+00 ... -6.82673794e-02
#   -5.76775883e-02 -3.45313182e-01]
#  [-8.66939700e-02  1.66240223e-01  1.57312700e+00 ... -1.20157065e+00
#   -1.13993068e+00  3.26845069e-01]
#  ...
#  [ 1.51260229e+00 -9.49435315e-01 -2.19061626e-01 ... -1.41537086e-03
#    3.66494418e-03 -2.13696185e-01]
#  [ 1.79886333e+00 -1.69979073e+00 -1.42182189e-01 ... -3.36155803e-02
#   -3.24705125e-02  3.31682753e-01]
#  [-5.89399721e-01  7.47828393e-01  1.78478144e+00 ...  8.65917860e-02
#    1.18083774e-01 -2.89299995e-01]]

# %% [markdown]
# # Model Training

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
model = Sequential([
    Dense(units=16, input_dim = 29,activation='relu'),
    Dense(units=24,activation='relu'),
    Dropout(0.5),
    Dense(units=20,activation='relu'),
    Dense(units=24,activation='relu'),
    Dense(units=1,activation='sigmoid'),
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                480
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                500
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                504
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 1,917
# Trainable params: 1,917
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,batch_size=15,epochs=5)
# Out:
# Epoch 1/5
# 199364/199364 [==============================] - 63s 315us/step - loss: 0.0096 - accuracy: 0.9978
# Epoch 2/5
# 199364/199364 [==============================] - 63s 317us/step - loss: 0.0039 - accuracy: 0.9994
# Epoch 3/5
# 199364/199364 [==============================] - 63s 317us/step - loss: 0.0035 - accuracy: 0.9993
# Epoch 4/5
# 199364/199364 [==============================] - 63s 318us/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 5/5
# 199364/199364 [==============================] - 64s 321us/step - loss: 0.0031 - accuracy: 0.9994

# %%
evaluation = model.evaluate(X_test, y_test)
print('Test Accuracy : {:.3f}'.format(evaluation[1]))
# Out:
# 85443/85443 [==============================] - 5s 59us/step
# Test Accuracy : 0.999

# %%
from sklearn.metrics import classification_report
predicted_classes = model.predict_classes(X_test)
print(classification_report(y_test, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.86      0.75      0.80       147
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.87      0.90     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
confusionMatrixlist = []
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predicted_classes)
plt.figure(figsize = (7,5))
sns.heatmap(cm, annot=True, fmt='g')
confusionMatrixlist.append(cm)

# %%
predicted_classes = model.predict_classes(X)
cm = confusion_matrix(y, predicted_classes)
plt.figure(figsize = (7,5))
sns.heatmap(cm, annot=True, fmt='g')
confusionMatrixlist.append(cm)

# %% [markdown]
# # Sampling
# Accuracy is 99.9% this doesnt mean it is god model, as you can see by confusion matrix and coefficient report False positive and False negative are high, so we need to sample data by **undersampling or oversampling!**

# %% [markdown]
# ## Undersampling

# %%
fraud_indices = np.array(data[data.Class == 1].index)
number_records_fraud = len(fraud_indices)
print(number_records_fraud)
# Out:
# 492

# %%
normal_indices = data[data.Class == 0].index
print(len(normal_indices))
random_normal_indices = np.random.choice(normal_indices, number_records_fraud, replace=False)
random_normal_indices = np.array(random_normal_indices)
print(len(random_normal_indices))
# Out:
# 284315
# 492

# %%
under_sample_indices = np.concatenate([fraud_indices,random_normal_indices])
print(len(under_sample_indices))
# Out:
# 984

# %%
under_sample_data = data.iloc[under_sample_indices,:]
X_undersample = under_sample_data.iloc[:,under_sample_data.columns != 'Class']
y_undersample = under_sample_data.iloc[:,under_sample_data.columns == 'Class']

# %%
X_undersample.shape
# Out:
# (984, 29)

# %%
X.shape
# Out:
# (284807, 29)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_undersample,y_undersample, test_size=0.3)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                480
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                500
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                504
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 1,917
# Trainable params: 1,917
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,batch_size=15,epochs=5)
# Out:
# Epoch 1/5
# 688/688 [==============================] - 0s 575us/step - loss: 0.4461 - accuracy: 0.8924
# Epoch 2/5
# 688/688 [==============================] - 0s 339us/step - loss: 0.1741 - accuracy: 0.9201
# Epoch 3/5
# 688/688 [==============================] - 0s 309us/step - loss: 0.1545 - accuracy: 0.9375
# Epoch 4/5
# 688/688 [==============================] - 0s 346us/step - loss: 0.1311 - accuracy: 0.9462
# Epoch 5/5
# 688/688 [==============================] - 0s 321us/step - loss: 0.1140 - accuracy: 0.9491

# %%
evaluation = model.evaluate(X_test, y_test)
print('Test Accuracy : {:.3f}'.format(evaluation[1]))
# Out:
# 296/296 [==============================] - 0s 167us/step
# Test Accuracy : 0.943

# %%
predicted_classes = model.predict_classes(X_test)
print(classification_report(y_test, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       150
#            1       1.00      0.88      0.94       146
#
#     accuracy                           0.94       296
#    macro avg       0.95      0.94      0.94       296
# weighted avg       0.95      0.94      0.94       296

# %%
cm = confusion_matrix(y_test, predicted_classes)
plt.figure(figsize = (7,5))
sns.heatmap(cm, annot=True, fmt='g')
confusionMatrixlist.append(cm)

# %%
predicted_classes = model.predict_classes(X)
cm = confusion_matrix(y, predicted_classes)
plt.figure(figsize = (7,5))
sns.heatmap(cm, annot=True, fmt='g')
confusionMatrixlist.append(cm)

# %% [markdown]
# ## OverSampling SMOTE

# %%
pip install -U imbalanced-learn
# Out:
# Requirement already up-to-date: imbalanced-learn in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn) (1.18.5)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.23 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn) (0.23.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn) (0.15.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.23->imbalanced-learn) (2.1.0)

# %%
from imblearn.over_sampling import SMOTE
X_resample, y_resample = SMOTE().fit_sample(X,y.values.ravel())

# %%
X_resample.shape

# %%
X.shape

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resample,y_resample,test_size=0.3)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,batch_size=15,epochs=5)
# Out:
# Epoch 1/5
# 398041/398041 [==============================] - 128s 321us/step - loss: 0.0328 - accuracy: 0.9889
# Epoch 2/5
# 398041/398041 [==============================] - 128s 323us/step - loss: 0.0130 - accuracy: 0.9965
# Epoch 3/5
# 398041/398041 [==============================] - 128s 322us/step - loss: 0.0109 - accuracy: 0.9973
# Epoch 4/5
# 398041/398041 [==============================] - 128s 322us/step - loss: 0.0098 - accuracy: 0.9977
# Epoch 5/5
# 398041/398041 [==============================] - 129s 325us/step - loss: 0.0092 - accuracy: 0.9979

# %%
evaluation = model.evaluate(X_test, y_test)
print('Test Accuracy : {:.3f}'.format(evaluation[1]))
# Out:
# 170589/170589 [==============================] - 11s 62us/step
# Test Accuracy : 0.998

# %%
predicted_classes = model.predict_classes(X_test)
print(classification_report(y_test, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85314
#            1       1.00      1.00      1.00     85275
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589

# %%
cm = confusion_matrix(y_test, predicted_classes)
plt.figure(figsize = (7,5))
sns.heatmap(cm, annot=True, fmt='g')
confusionMatrixlist.append(cm)

# %%
predicted_classes = model.predict_classes(X)
cm = confusion_matrix(y, predicted_classes)
plt.figure(figsize = (7,5))
sns.heatmap(cm, annot=True, fmt='g')
confusionMatrixlist.append(cm)

# %%
fig, ax =plt.subplots(3,2,figsize=(12, 10))
for i in [0,1,2,3,4,5]:
  sns.heatmap(confusionMatrixlist[i], annot=True, fmt='g', ax=ax.flat[i])
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
